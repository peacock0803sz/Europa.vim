# %%
# No kernelspec in notebook metadata — plain text fallback expected
print('hello')
# Out:
# hello

# %% [markdown]
# Notebook with no kernel metadata. Markdown cells still highlighted as markdown.
