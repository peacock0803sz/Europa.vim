# %% [markdown]
# # Heading One
#
# This is **bold** and *italic* text with `inline code`.
#
# A [link](https://example.com) and some _emphasis_.
#
# ```python
# def fibonacci(n):
#     """Return nth Fibonacci number."""
#     if n <= 1:
#         return n
#     return fibonacci(n - 1) + fibonacci(n - 2)
# ```
#
# More prose after the fenced block.

# %%
# Code cell following the markdown cell
result = fibonacci(10)
print(result)
# Out:
# 55
