# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install numpy

def compute(x: float) -> float:
    """Compute sine of x."""
    return np.sin(x)

# Regular Python after shell escape
result = compute(3.14)

# %%
# %timeit sum(range(1000))

class Processor:
    def run(self) -> None:
        pass
