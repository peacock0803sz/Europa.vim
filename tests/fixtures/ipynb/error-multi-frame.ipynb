# %%
from util import util_helper


def main():
    util_helper()

main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
# ----> 5     util_helper()
# File ~/proj/util.py:10, in util_helper()
#       9 def util_helper():
# ---> 10     nested_helper()
# File ~/proj/util.py:20, in nested_helper()
#      19 def nested_helper():
# ---> 20     raise RuntimeError("boom")
#
# RuntimeError: boom
