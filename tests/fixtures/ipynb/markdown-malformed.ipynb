# %% [markdown]
# # Malformed heading still rendered
#
# [unmatched bracket without closing paren
#
# **unterminated bold across lines
#
# regular paragraph that should still appear as raw text since parser may fallback
