# %%
import json
json.loads('not-json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ./tests/fixtures/external/x.py:10, in foo()
# File ./tests/fixtures/external/util.py:5, in helper()
#
# ValueError: bad json
