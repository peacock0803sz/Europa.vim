# %%
import json
json.loads('not-json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/lib/python3.12/json/__init__.py:123, in loads()
# File ~/.cache/europa-test/x.py:10, in foo()
# File ./util.py:5, in helper()
#
# ValueError: bad json
