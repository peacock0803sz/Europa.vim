# %% [markdown]
# # Heading 1
#
# Paragraph with **bold text** and *italic* and `inline_code` plus a [click here](https://example.com) link.
#
# - item 1
# - item 2
#
# 1. one
# 2. two
#
# > quoted line
#
# ---
#
# Strike: ~~strike~~ done.
#
# ```python
# print("hi")
# ```
