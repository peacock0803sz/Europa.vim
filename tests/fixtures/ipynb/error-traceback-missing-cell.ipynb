# %%
undefined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 undefined
#
# NameError: name 'undefined' is not defined
