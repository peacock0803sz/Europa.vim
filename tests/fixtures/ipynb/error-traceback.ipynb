# %%
def foo():
    pass

def bar():
    raise ValueError("oops")

bar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 def foo():
#       4     pass
# ----> 5     raise ValueError("oops")
#       6
#
# ValueError: oops
