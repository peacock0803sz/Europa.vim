# %%
# Cell 1: code with stream output
print("Hello from cell 1")
# Out:
# Hello from cell 1

# %% [markdown]
# # Cell 2: Markdown heading
#
# This is a markdown cell used to test cell type changes and split/join.

# %%
# Cell 3: code with execute_result output
x = 6 * 7
x
# Out:
# 42

# %% [raw]
# Cell 4: raw cell — plain text passthrough.
# Used to test raw type and changeCellType transitions.

# %%
# Cell 5: empty code cell — anchor for insertCell / deleteCell edge cases
# and split/join boundary tests
