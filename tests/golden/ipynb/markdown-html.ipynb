# %% [markdown]
# # Notebook Title
#
# This is a **markdown** cell with some content.
#
# ## Section 1
#
# Some text under section 1.
#
# ### Subsection
#
# More content here.

# %%
from IPython.display import Markdown, HTML
Markdown('## Rendered Markdown\n\nThis is **bold** and *italic*.')
# Out:
# ## Rendered Markdown
#
# This is **bold** and *italic*.

# %%
HTML('<h2>HTML Heading</h2><p>Paragraph with <strong>bold</strong> text.</p>')
# Out:
# <h2>HTML Heading</h2><p>Paragraph with <strong>bold</strong> text.</p>
