# %%
import subprocess
result = subprocess.run(['pytest', '--color=yes', '-v', 'test_example.py'], capture_output=True, text=True)
print(result.stdout)
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.0
# collecting ... collected 2 items
#
# test_example.py::test_pass PASSED
# test_example.py::test_fail FAILED
#
# ================================== FAILURES ===================================
# _________________________________ test_fail __________________________________
#
#     def test_fail():
# >       assert 1 == 2
# E       AssertionError: assert 1 == 2
# =========================== short test summary info ============================
# FAILED test_example.py::test_fail - AssertionError: assert 1 == 2
# 1 failed, 1 passed in 0.05s

# %%
import sys
print('warning message', file=sys.stderr)
# Out:
# warning message
