# %%
import sys
sys.stdout.write('\x1b[1m============================= test session starts ==============================\x1b[0m\n')
sys.stdout.write('platform darwin -- Python 3.14.2\n')
sys.stdout.write('\x1b[1mcollecting ...\x1b[0m collected 2 items\n\n')
sys.stdout.write('test_example.py::\x1b[1mtest_pass\x1b[0m \x1b[32mPASSED\x1b[0m\n')
sys.stdout.write('test_example.py::\x1b[1mtest_fail\x1b[0m \x1b[31mFAILED\x1b[0m\n\n')
sys.stdout.write('\x1b[31m1 failed\x1b[0m, \x1b[32m1 passed\x1b[0m in 0.05s\n')
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.14.2
# collecting ... collected 2 items
#
# test_example.py::test_pass PASSED
# test_example.py::test_fail FAILED
#
# 1 failed, 1 passed in 0.05s
# 46

# %%
import sys
sys.stderr.write('\x1b[33mwarning message\x1b[0m\n')
# Out:
# warning message
# 25
